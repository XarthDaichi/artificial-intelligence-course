# %%
import random
random.seed(666)
import math

# %%
def f(x, y):
    return 2*x**2*y**2 - 6*x*y**2 + 3*y**2 - 1
def g(x, y):
        return (x - 2)**2 + 2*(y-1)**2 + x

# %%
def gradient_f(x, y):
    f_x = (4*x - 6)*y**2
    f_y = (4*x**2 - 12*x + 6)*y
    return f_x, f_y
def gradient_g(x, y):
    g_x = 2*x - 3
    g_y = 4*(y - 1)
    return g_x, g_y

# %%
def gradient_descent(gradient, 
                     critical_point, 
                     f, 
                     max_iter=100, 
                     epsilon=1e-5, 
                     initial=None, 
                     lr=0.01):
    if initial is None:
        initial = random.random(), random.random()
    actual_min = f(*critical_point)
    xn, yn = initial
    for iter in range(max_iter):
        grad_x, grad_y = gradient(xn, yn)
        xn, yn = (xn - lr * grad_x, yn - lr*grad_y)
        estimated_min = f(xn, yn)
        print(f"{iter=:2} aprox_{iter} = ({xn=:}, {yn=:}) {actual_min}==?{estimated_min} ")
        if abs(actual_min - estimated_min) < epsilon:
            print(f"*** Convergence achieved *** at {iter=:}")
            break

# %%
gradient_descent(gradient_g, (1.5, 1), g, max_iter=150, lr=0.05)
# Out:
# iter= 0 aprox_0 = (xn=0.5605076840792715, yn=0.9226585231842115) 1.75==?2.6446092197461883
# iter= 1 aprox_1 = (xn=0.6544569156713445, yn=0.9381268185473692) 1.75==?2.4725996886221564
# iter= 2 aprox_2 = (xn=0.73901122410421, yn=0.9505014548378954) 1.75==?2.3340041289857028
# iter= 3 aprox_3 = (xn=0.8151101016937891, yn=0.9604011638703163) 1.75==?2.222210308447543
# iter= 4 aprox_4 = (xn=0.8835990915244102, yn=0.9683209310962531) 1.75==?2.1319572067827495
# iter= 5 aprox_5 = (xn=0.9452391823719691, yn=0.9746567448770025) 1.75==?2.05904412593578
# iter= 6 aprox_6 = (xn=1.0007152641347723, yn=0.979725395901602) 1.75==?2.000107366610704
# iter= 7 aprox_7 = (xn=1.0506437377212952, yn=0.9837803167212816) 1.75==?1.9524472067004122
# iter= 8 aprox_8 = (xn=1.0955793639491656, yn=0.9870242533770253) 1.75==?1.9138927908646086
# iter= 9 aprox_9 = (xn=1.136021427554249, yn=0.9896194027016202) 1.75==?1.882695914800189
# iter=10 aprox_10 = (xn=1.1724192847988242, yn=0.9916955221612962) 1.75==?1.857447053676061
# iter=11 aprox_11 = (xn=1.2051773563189419, yn=0.9933564177290369) 1.75==?1.8370086655978701
# iter=12 aprox_12 = (xn=1.2346596206870477, yn=0.9946851341832296) 1.75==?1.8204620124912418
# iter=13 aprox_13 = (xn=1.261193658618343, yn=0.9957481073465837) 1.75==?1.807064625866365
# iter=14 aprox_14 = (xn=1.2850742927565086, yn=0.996598485877267) 1.75==?1.7962162002307691
# iter=15 aprox_15 = (xn=1.3065668634808578, yn=0.9972787887018135) 1.75==?1.7874311882854919
# iter=16 aprox_16 = (xn=1.325910177132772, yn=0.9978230309614509) 1.75==?1.7803167448143324
# iter=17 aprox_17 = (xn=1.3433191594194946, yn=0.9982584247691607) 1.75==?1.774554951973583
# iter=18 aprox_18 = (xn=1.3589872434775452, yn=0.9986067398153285) 1.75==?1.7698884798499455
# iter=19 aprox_19 = (xn=1.3730885191297906, yn=0.9988853918522629) 1.75==?1.7661090086793156
# iter=20 aprox_20 = (xn=1.3857796672168115, yn=0.9991083134818103) 1.75==?1.7630478746307958
# iter=21 aprox_21 = (xn=1.3972017004951303, yn=0.9992866507854482) 1.75==?1.7605685081152966
# iter=22 aprox_22 = (xn=1.4074815304456172, yn=0.9994293206283585) 1.75==?1.7585603185585756
# iter=23 aprox_23 = (xn=1.4167333774010555, yn=0.9995434565026868) 1.75==?1.756933747302965
# iter=24 aprox_24 = (xn=1.42506003966095, yn=0.9996347652021494) 1.75==?1.7556162644485336
# iter=25 aprox_25 = (xn=1.4325540356948552, yn=0.9997078121617196) 1.75==?1.7545491288485167
# iter=26 aprox_26 = (xn=1.4392986321253696, yn=0.9997662497293757) 1.75==?1.7536847653402292
# iter=27 aprox_27 = (xn=1.4453687689128327, yn=0.9998129997835006) 1.75==?1.7529846413482613
# iter=28 aprox_28 = (xn=1.4508318920215495, yn=0.9998503998268005) 1.75==?1.7524175476026043
# iter=29 aprox_29 = (xn=1.4557487028193945, yn=0.9998803198614403) 1.75==?1.7519582059488374
# iter=30 aprox_30 = (xn=1.4601738325374551, yn=0.9999042558891522) 1.75==?1.7515861419486243
# iter=31 aprox_31 = (xn=1.4641564492837096, yn=0.9999234047113218) 1.75==?1.7512847718616278
# iter=32 aprox_32 = (xn=1.4677408043553386, yn=0.9999387237690575) 1.75==?1.7510406632131934
# iter=33 aprox_33 = (xn=1.4709667239198048, yn=0.999950979015246) 1.75==?1.7508429359260627
# iter=34 aprox_34 = (xn=1.4738700515278242, yn=0.9999607832121968) 1.75==?1.7506827772830715
# iter=35 aprox_35 = (xn=1.4764830463750418, yn=0.9999686265697575) 1.75==?1.7505530490763825
# iter=36 aprox_36 = (xn=1.4788347417375376, yn=0.999974901255806) 1.75==?1.7504479694172106
# iter=37 aprox_37 = (xn=1.480951267563784, yn=0.9999799210046448) 1.75==?1.7503628550137587
# iter=38 aprox_38 = (xn=1.4828561408074055, yn=0.9999839368037159) 1.75==?1.750293912424068
# iter=39 aprox_39 = (xn=1.484570526726665, yn=0.9999871494429727) 1.75==?1.7502380689757662
# iter=40 aprox_40 = (xn=1.4861134740539983, yn=0.9999897195543782) 1.75==?1.7501928358142242
# iter=41 aprox_41 = (xn=1.4875021266485984, yn=0.9999917756435026) 1.75==?1.7501561969735877
# iter=42 aprox_42 = (xn=1.4887519139837386, yn=0.9999934205148021) 1.75==?1.7501265195256084
# iter=43 aprox_43 = (xn=1.4898767225853649, yn=0.9999947364118417) 1.75==?1.7501024808010244
# iter=44 aprox_44 = (xn=1.4908890503268284, yn=0.9999957891294733) 1.75==?1.75008300943941
# iter=45 aprox_45 = (xn=1.4918001452941456, yn=0.9999966313035786) 1.75==?1.7500672376398934
# iter=46 aprox_46 = (xn=1.492620130764731, yn=0.9999973050428629) 1.75==?1.7500544624844552
# iter=47 aprox_47 = (xn=1.493358117688258, yn=0.9999978440342903) 1.75==?1.7500441146099395
# iter=48 aprox_48 = (xn=1.4940223059194322, yn=0.9999982752274322) 1.75==?1.7500357328324705
# iter=49 aprox_49 = (xn=1.494620075327489, yn=0.9999986201819457) 1.75==?1.7500289435932896
# iter=50 aprox_50 = (xn=1.49515806779474, yn=0.9999988961455566) 1.75==?1.7500234443099174
# iter=51 aprox_51 = (xn=1.495642261015266, yn=0.9999991169164453) 1.75==?1.7500189898906187
# iter=52 aprox_52 = (xn=1.4960780349137395, yn=0.9999992935331562) 1.75==?1.750015381811136
# iter=53 aprox_53 = (xn=1.4964702314223655, yn=0.999999434826525) 1.75==?1.7500124592668505
# iter=54 aprox_54 = (xn=1.496823208280129, yn=0.99999954786122) 1.75==?1.7500100920060402
# iter=55 aprox_55 = (xn=1.4971408874521162, yn=0.999999638288976) 1.75==?1.7500081745248233
# *** Convergence achieved *** at iter=55

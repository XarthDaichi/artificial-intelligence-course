# %% [markdown]
# Parte 1: (Respuesta de ChatGPT)
# Prompt:
# Bajo las siguientes reglas:
# - Las cajas A, B, C y la superficie (S) son los únicos objetos.
# - S no se puede mover del todo. Solo se mueven las cajas, una a la vez, nada más.
# - Una caja se puede mover si no tiene un objeto encima.
# - Ningún objeto se puede mover encima de sí mismo.
# - Una caja que pueda moverse puede moverse encima de otra caja siempre que esta última no tenga nada encima.
# - Una caja solo se puede mover encima de S o encima de otra caja
# - Cualquier caja, que se pueda mover, se puede mover encima de S.
#
# Asumí que se comienza con las cajas ordenas como  C encima de A y A encima de B y B encima de S
#
# Hacé el procedimiento para que las cajas queden ordenadas C encima de B y B encima de A y A encima de S
#
# **Respuesta de ChatGPT**:
# Para lograr que las cajas queden ordenadas como C encima de B, B encima de A y A encima de S, aquí está el procedimiento paso a paso:
#
# 1. Mueve la caja A a la superficie S.
# 2. Mueve la caja B a la superficie S.
# 3. Mueve la caja C a la superficie S.
# 4. Mueve la caja A encima de la caja B.
# 5. Mueve la caja B encima de la caja C.
# 6. Mueve la caja A encima de la superficie S.
#
# Al seguir este procedimiento, las cajas quedarán en el orden deseado: C encima de B, B encima de A y A encima de S.
#
# **Respuesta de Copilot**:
# Siguiendo las reglas que has establecido, vamos a ordenar las cajas C, B, A y la superficie S de manera que C quede encima de B, B encima de A, y A encima de S. Comencemos:
#
# 1. **Mover C encima de B**:
#    - Como C no tiene nada encima, podemos moverla directamente encima de B.
#
# 2. **Mover B encima de A**:
#    - Ahora que C está sobre B, podemos mover B encima de A.
#    - Para hacerlo, primero movemos C a un lado (encima de S o al lado de A).
#    - Luego, colocamos B encima de A.
#
# 3. **Mover A encima de S**:
#    - Finalmente, movemos A encima de S.
#
# El resultado final será: C encima de B, B encima de A y A encima de S. ¡Listo! 📦📦📦
#
# Source: Conversation with Bing, 2/26/2024
# (1) U.A.G.R.M. | Banco de Preguntas MATEMATICAS. https://files.uagrm.edu.bo/entidad/28/file/202001/MATEMATICAS.pdf.
# (2) Lista HTML: Cómo usar viñetas, listas ordenadas y desordenadas. https://www.freecodecamp.org/espanol/news/lista-html-como-usar-vinetas-listas-ordenadas-y-desordenadas/.
# (3) The Sounds of the Alphabet | A-B-C | Super Simple ABCs. https://www.youtube.com/watch?v=kmkdq8Sya54.
# (4) Eje de Abscisas y Ordenadas. Qué es, para que se usa y ejercicios. https://www.centroestudioscervantinos.es/eje-de-abscisas/.
# (5) undefined. http://apple.co/2nW5hPd.
#
#
# **Respuesta de Gemini**: \\
# **Pasos para ordenar las cajas:**
#
# 1. **Mover A a S:**
#     - Como A está encima de B y B está encima de S, primero hay que mover B a S.
#     - Ahora A está encima de S y se puede mover a S sin problemas.
#
# 2. **Mover C a B:**
#     - Ahora C está encima de S, pero no se puede mover directamente a B porque B está ocupado por A.
#     - Primero hay que mover B de vuelta a S.
#     - Ahora C se puede mover a B sin problemas.
#
# 3. **Mover A a B:**
#     - Finalmente, se puede mover A desde S a B.
#
# **Resultado final:**
#
# - C está encima de B.
# - B está encima de A.
# - A está encima de S.
#
# **Resumen de movimientos:**
#
# 1. B de A a S.
# 2. A de B a S.
# 3. C de A a B.
# 4. A de S a B.
#
# **Diagrama de los movimientos:**
#
# ```
# [Inicio]
# C
# A
# B
# S
#
# [Paso 1]
# C
# B
# A
# S
#
# [Paso 2]
# C
# S
# A
# B
#
# [Paso 3]
# B
# C
# S
# A
#
# [Paso 4]
# B
# C
# A
# S
#
# [Final]
# ```
#
# **Tiempo total:**
#
# El tiempo total para ordenar las cajas es de 4 pasos.
#
# **Comentarios:**
#
# * Esta es solo una de las posibles soluciones para ordenar las cajas.
# * Es posible que haya otras soluciones con menos pasos.
# * El número de pasos necesarios para ordenar las cajas depende de la configuración inicial de las cajas.

# %% [markdown]
# Fórmula notable:
# $$
# f(x) = x^2 + 2x + 1
# $$

# %% [markdown]
# Sea $f(x) = 2/3 * x^3 - 7/4 * x^2 + 3/2 * x + 1$. Encuentre los extremos máximos y mínimos si los hay. Diga si es máximo o mínimo. \\
#
# Sacando la primera derivada:
# $$
# f'(x) = 2 * x^2 - 7/2 * x + 3/2 \\
# $$
# Sacando los puntos críticos
# $$
# 2 * x^2 - 7/2 * x + 3/2 = 0 \\
# \\
# disc = b^2 - 4ac => 49/4 - 12 => 0.25\\
# $$
# Usando fórmula de Bhaskara
# $$
# -b +- \sqrt{disc} / 2 * a \\
# = - -3.50 + 0.5 / 4 = 0.75 \\
# = - -3.50 - 0.5 / 4 = 1.0 \\
# $$
# Encontrando si los puntos críticos son máximos o mínimos
# $$
# f''(x) = 4 * x - 7/2 \\
# f''(0.75) = 3 - 3.5 = - 0.5 \\
# f''(1) = 4 - 3.5 = 0.5 \\
# \\
#
# \therefore 0.75 = \text{máximo}
# \therefore 1 = \text{mínimo}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
import math as mt

def fun(x):
    return 2/3 * x ** 3 - 7/4 * x ** 2 + 3/2 * x + 1

def fun_prime(x):
    return 2 * x ** 2 - 7/2 * x + 3/2

def fun_prime_prime(x):
    return 4 * x - 7/2

def test_fun_instrumentado(start, end, inc):
    graph = []
    graph.append([])
    graph.append([])
    for i in range(start, end, inc):
        a = i
        graph[0] += [a]
        graph[1] += [fun(a)]
    return graph

solmin = fun(1)
solmax = fun(0.75)

g = test_fun_instrumentado(-5, 5, 1)
tempX = list(range(10, 85000, 10))
plt.plot(g[0], g[1],  "--", color="blue", label="f(x)") 
plt.plot(1, solmin, 'ro', label="mínimo")
plt.plot(0.75, solmax, 'go', label='maximo')
plt.legend()
plt.xlabel('x')
plt.ylabel("y")
plt.title("Función f(x)")
plt.show()

# %%
#### RESPUESTA ALBERTO
from sympy import symbols, diff, solve
import matplotlib.pyplot as plt

x = symbols('x')

def f(x):
    return 2/3 * x ** 3 - 7/4 * x ** 2 + 3/2 * x + 1

def test_fun_instrumentado(start, end, inc):
    graph = []
    graph.append([])
    graph.append([])
    nprange = np.arange(start, end, inc)
    for i in nprange:
        a = i
        graph[0] += [a]
        graph[1] += [f(a)]
    return graph

derivada = diff(f(x), x)

print(f'{derivada}')

puntos_criticos = solve(derivada, x)

print(f'{puntos_criticos}')

segunda_derivada = diff(derivada, x)
extremos = [(p, segunda_derivada.subs(x,p)) for p in puntos_criticos]

minimos = [p[0] for p in extremos if p[1] > 0]
maximos = [p[0] for p in extremos if p[1] < 0]

print("Mínimos: (", minimos[0], f(minimos[0]), ")")
print("Máximos: (", maximos[0], f(maximos[0]), ")")

g = test_fun_instrumentado(0, 1.5, 0.01)
plt.plot(g[0], g[1], color="blue", label="f(x)") 
plt.plot(minimos[0], f(minimos[0]), 'ro', label="mínimo")
plt.plot(maximos[0], f(maximos[0]), 'go', label='maximo')
plt.legend()
plt.xlabel('x')
plt.ylabel("y")
plt.title("Función f(x)")
plt.show()
# Out:
# 2.0*x**2 - 3.5*x + 1.5
# [0.750000000000000, 1.00000000000000]
# Mínimos: ( 1.00000000000000 1.41666666666667 )
# Máximos: ( 0.750000000000000 1.42187500000000 )
